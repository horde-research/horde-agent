# %%
from core.llm.client import LLMClient

client = LLMClient(
    provider="gemini",
    api_key="AIzaSyDTlWnF7zfNAY66742nOGy2iHCYk32ZypQ",
    model="gemini-2.5-flash",
)

# %%
from core.llm.client import LLMRequest

request = LLMRequest(
    request_id="123",
    user_message="What is the capital of France?",
)

# %%
client.generate_json_sync(
    request=request
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 await client.generate_json_sync(
#       2     request=request
#       3 )
#
# File ~/Desktop/hugging_face/horde-agent/core/llm/client.py:459, in LLMClient.generate_json_sync(self, request)
#     457 def generate_json_sync(self, request: LLMRequest) -> LLMResponse:
#     458     """Synchronous wrapper around :meth:`generate_json`."""
# --> 459     return asyncio.run(self.generate_json(request))
#
# File /opt/homebrew/Cellar/python@3.11/3.11.14_3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/runners.py:186, in run(main, debug)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    182     asyncio.run(main())
#     183 """
#     184 if events._get_running_loop() is not None:
# ...
